# %% [markdown]
# <a href="https://colab.research.google.com/github/shuai-yang/SVM-classifier/blob/main/HS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pwd   (block comment ctrl + /)
# %ls
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive/   
# %pwd
# %ls
# Out:
# /content/drive/My Drive

# %%
# %cd research/
# Out:
# /content/drive/My Drive/research

# %%
#read file
import pandas as pd
df = pd.read_csv('texts.txt', header=None, sep="\n", names=['userTweets']) #separator is \n # do not use index_col=0
df['userID'] = df.index + 1
df = df.dropna()
df
#sampleDataset = df.head()
#sampleUserTweets = sampleDataset['userTweets'][0]
# Out:
#                                             userTweets
# 0    it was fun while it but but i gotta gtf home😂 ...
# 1    RT #USER#: George Floyd family to get $27milli...
# 2    RT #USER#: Russ's Moon Ball is one of the pret...
# 3    Romanian graftbuster’s firing violated rights,...
# 4    Switzerland referendum: Voters support ban on ...
# ..                                                 ...
# 195  I have 63 new followers from USA 🇺🇸, Italy 🇮🇹,...
# 196  RT #USER#: This squashed nug has us absolutely...
# 197  I don't know about this one #URL# So #USER# sa...
# 198  RT #USER#: I need a fuck it day. •Definition: ...
# 199  #USER# #USER# #USER# #USER# #USER# But these w...
#
# [200 rows x 1 columns]

# %%
df = df.dropna()
df
#from nltk import word_tokenize
# '''
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# import os
# import pandas as pd
# df = pd.read_csv('texts.txt', header=None, sep="\n", names=['userTweets'] ) 
# df
# '''
# Out:
# Empty DataFrame
# Columns: []
# ...
